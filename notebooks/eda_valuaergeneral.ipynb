# %%
from pathlib import Path
import pandas as pd
import numpy as np

DATA_DIR = Path("../data").resolve()

# %%
fp = DATA_DIR / "01_interim/valuergeneral/001_SALES_DATA_NNME.csv"
df = pd.read_csv(fp)

# %%
display(df.iloc[:,0:19].head())
df.iloc[:,0:19].info()
# Out:
#    Unnamed: 0    fileType  districtCode downloadDateTime submitterUserId  \
# 0           0  RTSALEDATA         103.0   20220103 01:26          VALNET
# 1           1         NaN           NaN              NaN             NaN
# 2           2         NaN           NaN              NaN             NaN
# 3           3         NaN           NaN              NaN             NaN
# 4           4         NaN           NaN              NaN             NaN
#
#    districtCode.1  propertyId  saleCounter downloadDateTime.1 propertyName  \
# 0           103.0   3177743.0          1.0     20220103 01:27          NaN
# 1           103.0   1177555.0          2.0     20220103 01:27          NaN
# 2           103.0   4400995.0          3.0     20220103 01:27          NaN
# 3           103.0   1179345.0          4.0     20220103 01:27          NaN
# 4           103.0   2939227.0          5.0     20220103 01:27          NaN
#
#   propertyUnitNumber propertyHouseNumber    propertyStreetName  \
# ...

# %% [markdown]
# -

# %%
display(df.iloc[:,19:].head())
df.iloc[:,19:].info()
# Out:
#    purchasePrice zoning natureOfProperty primaryPurpose  strataLotNumber  \
# 0       352000.0    NaN                R      RESIDENCE             20.0
# 1      2510000.0     B1                R      RESIDENCE              NaN
# 2      1750000.0     R2                V    VACANT LAND              NaN
# 3      1200000.0     R2                R      RESIDENCE              NaN
# 4       650000.0     R2                R      RESIDENCE              NaN
#
#   componentCode  saleCode  percentInterestOfSale dealingNumber  \
# 0           NaN       NaN                    0.0      AR766800
# 1           BBA       NaN                    0.0      AR766902
# 2           AAI       NaN                    0.0      AR767758
# 3           ABJ       NaN                    0.0      AR770365
# 4           AAE       NaN                    0.0      AR771633
#
#    districtCode.2  ...  propertyLegalDescription  districtCode.3 propertyId.2  \
# ...

# %%
df.saleCounter.value_counts()
df.purchaserVendor.value_counts()
# Out:
# purchaserVendor
# P    29257
# V    29001
# Name: count, dtype: int64

# %%
df.loc[:,"propertyId.1"].isna().sum(), df.loc[:,"propertyId"].isna().sum()
# Out:
# (38112, 38127)

# %%
[df.primaryPurpose == 'RESIDENCE']
[df.primaryPurpose == 'RESIDENCE']

# %%
df.head()
# Out:
#    Unnamed: 0    fileType  districtCode downloadDateTime submitterUserId  \
# 0           0  RTSALEDATA         103.0   20220103 01:26          VALNET
# 1           1         NaN           NaN              NaN             NaN
# 2           2         NaN           NaN              NaN             NaN
# 3           3         NaN           NaN              NaN             NaN
# 4           4         NaN           NaN              NaN             NaN
#
#    districtCode.1  propertyId  saleCounter downloadDateTime.1 propertyName  \
# 0           103.0   3177743.0          1.0     20220103 01:27          NaN
# 1           103.0   1177555.0          2.0     20220103 01:27          NaN
# 2           103.0   4400995.0          3.0     20220103 01:27          NaN
# 3           103.0   1179345.0          4.0     20220103 01:27          NaN
# 4           103.0   2939227.0          5.0     20220103 01:27          NaN
#
# ...
