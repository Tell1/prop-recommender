# %%
from pathlib import Path

import pandas as pd

import geopandas as gpd
from geopandas.geodataframe import GeoDataFrame

DATA_DIR = Path("../data").resolve()


filepath = DATA_DIR / "00_raw" / "nationalmaps" / "32350_ERP_Age_Sex_SA2_2022_gpkg" / "SA2 ERP by Age and Sex GeoPackage 2022.gpkg"
metadata_filepath = DATA_DIR / "00_raw" / "nationalmaps" / "metadata"
digital_boundaries_filepath = metadata_filepath / "SA2_2021_AUST_GDA2020.shp"
variable_mapping = metadata_filepath = metadata_filepath / "variable_indixes_mapping.json"
save_path = DATA_DIR / "01_interim" / "nationalmaps" / "32350_ERP_Age_Sex_SA2_2022_gpkg.shp"

# %%
digital_boundaries: GeoDataFrame = gpd.read_file(digital_boundaries_filepath)

# %%
import fiona
gdf = gpd.read_file(filepath)
gdf_raw = gdf.copy()

# %%
gdf.head(1)
# Out:
#    STE_CODE21       STE_NAME21 GCC_CODE21   GCC_NAME21  SA4_CODE21  \
# 0           1  New South Wales      1RNSW  Rest of NSW         101
#
#        SA4_NAME21  SA3_CODE21  SA3_NAME21  SA2_CODE21 SA2_NAME21  ...  P45_49  \
# 0  Capital Region       10102  Queanbeyan   101021007  Braidwood  ...     280
#
#    P50_54  P55_59  P60_64  P65_69  P70_74  P75_79  P80_84  P85_and_over  \
# 0     318     355     447     343     270     260     128            87
#
#                                             geometry
# 0  POLYGON ((149.58423 -35.44427, 149.58444 -35.4...
#
# [1 rows x 70 columns]

# %%
print(set(gdf.SA3_NAME21.unique()))
# Out:
# {'Jimboomba', 'Albury', 'Toowoomba', 'Mandurah', 'Far North', 'Hobsons Bay', 'The Hills District', 'Swan', 'Armadale', 'Nundah', 'Moreland - North', 'Kimberley', 'Wangaratta - Benalla', 'Sherwood - Indooroopilly', 'Cronulla - Miranda - Caringbah', 'Lord Howe Island', 'Hobart - South and West', 'Chatswood - Lane Cove', 'Gladstone', 'Monash', 'Banyule', 'Manly', 'Wellington', 'Fairfield', 'Chermside', 'Goulburn - Mulwaree', 'Burnie - Ulverstone', 'Gawler - Two Wells', 'Wodonga - Alpine', 'South East Coast', 'South Coast', 'Port Phillip', 'Manningham - West', 'Pennant Hills - Epping', 'Hervey Bay', 'Joondalup', 'Carlingford', 'Innisfail - Cassowary Coast', 'Illawarra Catchment Reserve', 'Perth City', 'Maryborough - Pyrenees', 'Shepparton', 'North Sydney - Mosman', 'Darwin City', 'Canberra East', 'Holdfast Bay', 'Mid West', 'Young - Yass', 'Cocos (Keeling) Islands', 'Hornsby', 'Stirling', 'Whitehorse - East', 'Bowen Basin - North', 'Redcliffe', 'Mackay', 'Kingston', 'Melville', 'Bankstown', 'Buderim', 'Mornington Peninsula', 'Outback - South', 'Murray River - Swan Hill', 'Woden Valley', 'Great Lakes', 'Lower Hunter', 'St Marys', 'Mitcham', 'Marion', 'Devonport', 'Whitehorse - West', 'Outback - North', 'Nerang', 'Eastern Suburbs - South', 'Onkaparinga', 'Cairns - South', 'Darwin Suburbs', 'South Canberra', 'Mildura', 'Gungahlin', 'Cleveland - Stradbroke', 'Glenelg - Southern Grampians', 'Mundaring', 'Hawkesbury', 'Leichhardt', 'Prospect - Walkerville', 'Grampians', 'Loganlea - Carbrook', 'Eastern Suburbs - North', 'Blue Mountains', 'Central Highlands (Tas.)', 'Caboolture Hinterland', 'Snowy Mountains', 'Mt Gravatt', 'Hobart - North East', 'Brimbank', 'Bribie - Beachmere', 'West Pilbara', 'Charles Sturt', 'Baulkham Hills', 'Warrnambool', 'Blacktown', 'Stonnington - West', 'Gympie - Cooloola', 'Ku-ring-gai', 'Bringelly - Green Valley', 'Ryde - Hunters Hill', 'Orange', 'Brisbane Inner - East', 'Surf Coast - Bellarine Peninsula', 'Tumut - Tumbarumba', 'Playford', 'Broken Hill and Far West', 'Dapto - Port Kembla', 'Broadbeach - Burleigh', 'Geelong', 'Tullamarine - Broadmeadows', 'Forest Lake - Oxley', 'Hurstville', 'Hobart Inner', 'Wagga Wagga', 'Sandgate', 'Belmont - Victoria Park', 'Knox', 'Esperance', 'Wollongong', 'Penrith', 'Maroochy', 'Frankston', 'Cockburn', 'Newcastle', 'South Perth', 'Granite Belt', 'Port Adelaide - West', 'Canterbury', 'Gold Coast Hinterland', 'Darling Downs - East', 'Taree - Gloucester', 'Wheat Belt - South', 'Ormeau - Oxenford', 'Noosa Hinterland', 'Robina', 'Litchfield', 'Bunbury', 'Marrickville - Sydenham - Petersham', 'Murray and Mallee', 'Shoalhaven', 'Sorell - Dodges Ferry', 'Port Adelaide - East', 'Kalamunda', 'Queanbeyan', 'Yorke Peninsula', 'Gippsland - South West', 'Brisbane Inner - West', 'Tablelands (East) - Kuranda', 'North Lakes', 'Lower North', 'Cairns - North', 'Caboolture', 'Bayside', 'Limestone Coast', 'Coffs Harbour', 'Whitsunday', 'Southport', 'Gosford', 'Bundaberg', 'Parramatta', 'Bathurst', 'Lake Macquarie - West', 'Upper Goulburn Valley', 'Keilor', 'Ipswich Hinterland', 'Meander Valley - West Tamar', 'Lower Murray', 'Alice Springs', 'Gold Coast - North', 'Botany', 'Manjimup', 'Heathcote - Castlemaine - Kyneton', 'Fremantle', 'Bourke - Cobar - Coonamble', 'Richmond Valley - Hinterland', 'Tuggeranong', 'Yarra', 'Inverell - Tenterfield', 'Wanneroo', 'Rockingham', 'Burnett', 'Nillumbik - Kinglake', 'Unley', 'Uriarra - Namadgi', 'Central Highlands (Qld)', 'Charters Towers - Ayr - Ingham', 'Fleurieu - Kangaroo Island', 'Maribyrnong', 'Palmerston', 'Capalaba', 'Mount Druitt', 'Surfers Paradise', 'Wheat Belt - North', 'Adelaide Hills', 'Sunshine Coast Hinterland', 'Loddon - Elmore', 'Burnside', 'Upper Hunter', 'Ballarat', 'Bendigo', 'North East', 'Melton - Bacchus Marsh', 'Blue Mountains - South', 'Brisbane Inner - North', 'Armidale', 'Baw Baw', 'Hobart - North West', 'Daly - Tiwi - West Arnhem', 'Maitland', 'Springwood - Kingston', 'Holland Park - Yeronga', 'Brisbane Inner', 'Casey - North', ' ...

# %%
gdf.loc[gdf.SA3_NAME21.isin(['Manly','Noosa']), [c for c in gdf.columns if c.startswith('P')]+['SA3_NAME21']].groupby('SA3_NAME21').sum()
# Out:
#             Persons  P0_4  P5_9  P10_14  P15_19  P20_24  P25_29  P30_34  \
# SA3_NAME21
# Manly         43324  2349  2483    2799    2572    2159    2766    3379
# Noosa         47603  1948  2793    3195    2755    1649    1550    2034
#
#             P35_39  P40_44  P45_49  P50_54  P55_59  P60_64  P65_69  P70_74  \
# SA3_NAME21
# Manly         3162    3104    3275    3138    2932    2448    1819    1655
# Noosa         2618    3127    3371    3357    3253    3428    3237    3445
#
#             P75_79  P80_84  P85_and_over
# SA3_NAME21
# Manly         1470     913           901
# Noosa         2768    1622          1453
